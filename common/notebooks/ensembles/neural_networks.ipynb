# %% [markdown]
# # Краткое введение в [нейронные сети](https://ru.wikipedia.org/wiki/%D0%9D%D0%B5%D0%B9%D1%80%D0%BE%D0%BD%D0%BD%D0%B0%D1%8F_%D1%81%D0%B5%D1%82%D1%8C)
#
# Нейрон в Искусственной Нейронной Сети (ИНС) является упрощением [модели биологического нейрона.](https://ru.wikipedia.org/wiki/%D0%9C%D0%BE%D0%B4%D0%B5%D0%BB%D1%8C_%D0%B1%D0%B8%D0%BE%D0%BB%D0%BE%D0%B3%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%BE%D0%B3%D0%BE_%D0%BD%D0%B5%D0%B9%D1%80%D0%BE%D0%BD%D0%B0)

# %%
# Источник - https://aldebaran.ru/author/alekseevich_kan_kania/kniga_neyironnyiyi_seti_yevolyuciya/read/
Image('img/neuron.jpg', width='85%')

# %% [markdown]
# В ИНС могут использоваться различные [функции активации.](https://ru.wikipedia.org/wiki/%D0%A4%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D1%8F_%D0%B0%D0%BA%D1%82%D0%B8%D0%B2%D0%B0%D1%86%D0%B8%D0%B8) Наиболее распространены [логистическая функция, гиперболический тангенс и RELU.](https://aisimple.ru/8-funkcii-aktivacii-v-iskusstvennyh-nejronnyh-setjah.html)

# %% [markdown]
# Наиболее современные базовые архитектуры нейронных сетей:
# - [Однослойный и многослойный перцептрон](https://ru.wikipedia.org/wiki/%D0%9F%D0%B5%D1%80%D1%86%D0%B5%D0%BF%D1%82%D1%80%D0%BE%D0%BD)
#   - [Глубокое обучение](https://ru.wikipedia.org/wiki/%D0%93%D0%BB%D1%83%D0%B1%D0%BE%D0%BA%D0%BE%D0%B5_%D0%BE%D0%B1%D1%83%D1%87%D0%B5%D0%BD%D0%B8%D0%B5)
# - [Сверточная нейронная сеть](https://ru.wikipedia.org/wiki/%D0%A1%D0%B2%D1%91%D1%80%D1%82%D0%BE%D1%87%D0%BD%D0%B0%D1%8F_%D0%BD%D0%B5%D0%B9%D1%80%D0%BE%D0%BD%D0%BD%D0%B0%D1%8F_%D1%81%D0%B5%D1%82%D1%8C)
#   - [Капсульная нейронная сеть](https://habr.com/ru/post/417223/)
# - [Рекуррентная нейронная сеть](https://ru.wikipedia.org/wiki/%D0%A0%D0%B5%D0%BA%D1%83%D1%80%D1%80%D0%B5%D0%BD%D1%82%D0%BD%D0%B0%D1%8F_%D0%BD%D0%B5%D0%B9%D1%80%D0%BE%D0%BD%D0%BD%D0%B0%D1%8F_%D1%81%D0%B5%D1%82%D1%8C)
# - [Автокодировщик](https://ru.wikipedia.org/wiki/%D0%90%D0%B2%D1%82%D0%BE%D0%BA%D0%BE%D0%B4%D0%B8%D1%80%D0%BE%D0%B2%D1%89%D0%B8%D0%BA)
#   - [Вариационный автокодировщик](https://habr.com/ru/post/429276/)
# - [Генеративно-состязательная сеть](https://ru.wikipedia.org/wiki/%D0%93%D0%B5%D0%BD%D0%B5%D1%80%D0%B0%D1%82%D0%B8%D0%B2%D0%BD%D0%BE-%D1%81%D0%BE%D1%81%D1%82%D1%8F%D0%B7%D0%B0%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D0%B0%D1%8F_%D1%81%D0%B5%D1%82%D1%8C)
# - [Механизм внимания в нейронных сетях](https://neerc.ifmo.ru/wiki/index.php?title=%D0%9C%D0%B5%D1%85%D0%B0%D0%BD%D0%B8%D0%B7%D0%BC_%D0%B2%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D1%8F)
# - [Квантовые нейронные сети](https://habr.com/ru/company/raiffeisenbank/blog/523932/)
#
# В целом можно отметить, что наиболее современные подходы к решению задач машинного обучения в самых различных областях (обработка текста, звука, изображений, видео) представляют собой **единую** сложную нейронную сеть (так называемое end-to-end решение).

# %% [markdown]
# ## Обучение нейронной сети
#
# Для обучения нейронной сети используется [метод обратного распространения ошибки.](https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D0%BE%D0%B1%D1%80%D0%B0%D1%82%D0%BD%D0%BE%D0%B3%D0%BE_%D1%80%D0%B0%D1%81%D0%BF%D1%80%D0%BE%D1%81%D1%82%D1%80%D0%B0%D0%BD%D0%B5%D0%BD%D0%B8%D1%8F_%D0%BE%D1%88%D0%B8%D0%B1%D0%BA%D0%B8) Англ. - backpropagation.
#
# [Пример реализации на Python.](https://pyimagesearch.com/2021/05/06/backpropagation-from-scratch-with-python/)

# %% [markdown]
# ## Практический пример. [Задача распознавания рукописных цифр.](https://scikit-learn.org/stable/auto_examples/classification/plot_digits_classification.html)

# %%
# Источник - https://medium.com/analytics-vidhya/applying-ann-digit-and-fashion-mnist-13accfc44660
Image('img/mnist.gif', width='50%')

# %% [markdown]
# ### Использование библиотеки scikit-learn
#
# В [библиотеке scikit-learn](https://scikit-learn.org/stable/modules/neural_networks_supervised.html) для многослойного персептрона используются классы [MLPClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html) и [MLPRegressor.](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPRegressor.html)
#
# - Решения с использованием scikit-learn
#     - https://dmkothari.github.io/Machine-Learning-Projects/MLP_with_MNIST.html
#     - https://johdev.com/jupyter/2020/03/02/Sklearn_MLP_for_MNIST.html

# %% [markdown]
# ### Использование библиотеки [TensorFlow](https://ru.wikipedia.org/wiki/TensorFlow)
#
# - [Решение с использованием TensorFlow.](https://www.tensorflow.org/datasets/keras_example)
# - [Решение с использованием TensorFlow и сверточной нейронной сети.](https://www.tensorflow.org/tutorials/images/cnn)
# - [Решение с использованием TensorFlow и квантовой нейронной сети.](https://www.tensorflow.org/quantum/tutorials/mnist)

# %% [markdown]
# ### Использование библиотеки [PyTorch](https://ru.wikipedia.org/wiki/PyTorch)
#
# - [Решение с использованием PyTorch.](https://www.projectpro.io/article/exploring-mnist-dataset-using-pytorch-to-train-an-mlp/408)
# - [Решение с использованием PyTorch и сверточной нейронной сети.](https://nextjournal.com/gkoehler/pytorch-mnist)

# %% [markdown]
# ## Дополнительные источники
#
# - [Сравнение TensorFlow и PyTorch №1](https://python-school.ru/blog/tensorflow-vs-pytorch/)
# - [Сравнение TensorFlow и PyTorch №2](https://habr.com/ru/company/ru_mts/blog/565456/)
